# %%
#Student Name: Zakariya Oulhadj
#Student e-mail: oulhadjz@roehampton.ac.uk
#Module: Software Development 1

# %% [markdown]
# ## Background
#
#
# In the wake of the SARS-CoV-2 pandemic, causing COVID-19 disease, international air travel effectively stopped. With cases within many countries declining, understanding how to safely re-open international travel and to which countries is of key importance for the United Kingdom. In particular, it is imperative to determine a risk-based entry strategy, and for that strategy to be flexible in order to quickly react to changing disease prevalence.  Prevalence is defined as the total number of cases existing in a country’s population divided by the total country population worldwide.
#
# UK government researchers were tasked with estimating the weekly number of infectious travellers from 25 countries that have most flights to the UK. They modelled a country’s prevalence by taking the number of cases in the past 7 days, dividing it by an asymptomatic factor (0.5) and then dividing the result by the total population of each country.
#
# To implement their model, they turned to software developers to gather the relevant data, extract the key metrics per country and calculate the disease prevalence per week. This Notebook uses four sources of real data:
#
# 1. EUnonEUcombinedTravel.css : Travel Data provided by Dr Taylor, but freely available from Eurostat website. In the file there is a row for every airport-country combination with how many passengers are expected in 1 month from that country to that airport. It does not include the country's name, but only their ISO3 codes.
#
# 2. ISOcodes.csv: provided by Dr Taylor, this file has the ISO2, ISO3 and country names in it. It is necessary to  match this with the Travel Data to find out which countries the ISO3’s are referring to.
#
# 3. WorldPopData.csv : This is a database of all the world population per country obtained from https://worldpopulationreview.com/countries
#
# 4. WHOCOVID.csv : Database from the World Health Organization with information on the most recent COVID numbers per country, obtained from https://covid19.who.int/table
#
#
# This work is based on the paper: Taylor, R., McCarthy, C. A., Patel, V., Moir, R., Kelly, L., & Snary, E. (2020). The risk of introducing SARS-CoV-2 to the UK via international travel in August 2020. medRxiv.

# %% [markdown]
# ## Functions used throughout the code

# %%
# Function to extract info on CSV. Needs a csv file as input.
def extract_csv(filename):
    # importing csv module 
    import csv 
    # arrays to store data
    fields = [] # for top header, usually strings
    rows = [] # for actual data, mix of strings and numbers

    # read csv file
    # open simplifies exception handling and automatically closes the CSV file.
    with open(filename, "r") as csvfile:
        # create a csv reader object
        # maps the data into lists
        csvreader = csv.reader(csvfile)

        # extract field names through first row
        fields = next(csvreader)

        # extracting each data row one by one
        for row in csvreader:
            rows.append(row)
    
    d = dict();
    d["fields"] = fields
    d["data"] = rows
    
    # returns a dictionary with fields and data
    return d

# %%
# make dictionary to investigate which are the top 25 travelling countries
# input is travel_list[1]
def add_to_countries(rows):
    max_dictionary = {}
    for row in rows:
        if str(row[2]) in max_dictionary.keys():
            max_dictionary[str(row[2])] = max_dictionary[str(row[2])] + int(row[4])
        else:
            max_dictionary.setdefault(str(row[2]), int(row[4]))

    # Used Lambda function, a function without a name, as a sorting mechanism 
    # allows us to sort our dictionary by value
    # reverse=True means that we want our data to be sorted in descending order
    return sorted(max_dictionary.items(), key = lambda x:x[1], reverse=True)

# %%
# make dictionary to investigate which are the top 25 UK airports
# input is travel_list[1]

def add_to_airports(rows):
    max_airports = {}
    for row in rows:
        if str(row[1]) in max_airports.keys():
            max_airports[str(row[1])] = max_airports[str(row[1])] + int(row[4])
        else: 
            max_airports.setdefault(str(row[1]), int(row[4]))
            
        # Used Lambda function, a function without a name, as a sorting mechanism 
        # allows us to sort our dictionary by value
        # reverse = True means that we want our data to be sorted in descending order
    return sorted(max_airports.keys(), key = lambda x:x[1], reverse = True)

# %%
# matches the top countries list to the country name
def matchData(list1,list2):
    newList = []
    i = 0
    j = 0
    while i < len(list1):
        while j < len(list2[1]):
            if list1[i][0] == list2[1][j][2]:
                b = str(list1[i][0]), str((list2[1][j][0])), str(list1[i][1])
                newList.append(b)
            j = j + 1
        i = i + 1
        j = 0
    return newList

# %%
# needs as input matchedCountries, who_covid_list, world_pop_list
def calculatePrevalence(list1, list2, list3):

    newList = []
    i = 0
    j = 0
    k = 0
    

    while i < len(list1):
        while j < len(list2[1]):
            while k < len(list3[1]):
                if list1[i][1] == list2[1][j][0] or list1[i][1] == "Czech Republic" and list2[1][j][0] == "Czechia":

                    # lists all the countries covid == list all countries population
                    if list2[1][j][0] == list3[1][k][1] or list2[1][j][0] == "Czechia" and list3[1][k][1] == "Czech Republic" or list2[1][j][0] == "United States of America" and list3[1][k][1] == "United States":
                        
                        # number of cases in last 7 days/ 0.5*total population*1000 because the CSV misinterprets data
                        prevalence = float(list2[1][j][4]) / (0.5 * float(list3[1][k][2]) * 1000)
                        b = str(list1[i][0]), str((list1[i][1])), str(prevalence)
                        newList.append(b)
                k = k + 1
            j = j + 1
            k = 0
        i = i + 1
        j = 0
        
    return newList

# %%
# sorting function for prevalence
def sortList(list1):
    def getKey(item):
        return item[2]
    return sorted(list1, key = getKey, reverse = True)

# %%
# needs as input the travel list and sorted Prevalence
def airpotPrevalence(list1, list2):

    top_airports = []
    for i in list1[1]:
        for j in list2:
            # if country code matches with airport
            if j[0] == i[2]:
                b = float(i[4]) * float(j[2])
                c = i[1], i[2], b
                top_airports.append(c)
    
    return top_airports

# %%
# Aggregate to get the total number of infected people arriving to each airport 
# input is airport_list

def airports_infected(rows):
    max_airports = {}
    for row in rows:
        if str(row[0]) in max_airports.keys():
            max_airports[str(row[0])] = max_airports[str(row[0])] + int(row[2])
        else: 
            max_airports.setdefault(str(row[0]), int(row[2]))
            
    # Used Lambda function, a function without a name, as a sorting mechanism 
    # allows us to sort our dictionary by value
    # reverse = True means that we want our data to be sorted in descending order
    return sorted(max_airports.items(), key = lambda x:x[1], reverse = True)

# %%
# number of infected people arriving from each country 
# input is airport_list

def countries_infected(rows):
    max_airports = {}
    for row in rows:
        if str(row[1]) in max_airports.keys():
            max_airports[str(row[1])] = max_airports[str(row[1])] + int(row[2])
        else: 
            max_airports.setdefault(str(row[1]), int(row[2]))
            
        # Used Lambda function, a function without a name, as a sorting mechanism 
        # allows us to sort our dictionary by value
        # reverse = True means that we want our data to be sorted in descending order
    return sorted(max_airports.items(), key = lambda x:x[1], reverse = True)

# %% [markdown]
# # Research Questions
#
# 1. Which are the top 25 countries with COVID travelling by air into the UK?
#
# 2. Which are the top 25 UK airports people use to travel?
#
# 3. What is the disease prevalence to the top 25 countries travelling into the UK?
#
# 4. What is the number of infected people from the top 25 countries arriving at each UK airport?
#
# 5. a. What is the total number of infected people arriving to each airport? b. What is the total number of infected people arriving from each country in the top 25?

# %%
#1. Investigate which are the top 25 countries travelling into the UK
#make sure they include country code, country names and passengers 

# Get CSV data
# csv file name 
travelData = "data/EUnonEUcombinedTravel.csv" # provided by Dr Taylor
countryCode ="data/ISOcodes.csv"  # provided by Dr Taylor
worldPopData = "data/WorldPopData.csv" # obtained from https://worldpopulationreview.com/countries
whoCOVID = "data/WHOCOVID.csv" # obtained from https://covid19.who.int/table

#TIP: mac and pc have different ways of accessing a file

# Get dictionaries out of the data (keys:fields, values:data)
travel_dict = extract_csv(travelData)
world_pop_dict = extract_csv(worldPopData)
who_covid_dict = extract_csv(whoCOVID)
country_code_dict = extract_csv(countryCode)

# get lists of the data in dictionaries
travel_list = list(travel_dict.values())
world_pop_list = list(world_pop_dict.values())
who_covid_list = list(who_covid_dict.values())
country_code_list = list(country_code_dict.values())

# manipulate data
sorted_countries = add_to_countries(travel_list[1])
top_countries = sorted_countries [:25]
matchedCountries = matchData(top_countries,country_code_list)
matchedCountries
# Out:
# [('ESP', 'Spain', '2706321'),
#  ('USA', 'United States of America', '1124137'),
#  ('ITA', 'Italy', '864412'),
#  ('FRA', 'France', '746692'),
#  ('GRC', 'Greece', '723248'),
#  ('DEU', 'Germany', '651094'),
#  ('IRL', 'Ireland', '607160'),
#  ('PRT', 'Portugal', '531283'),
#  ('NLD', 'Netherlands', '468559'),
#  ('TUR', 'Turkey', '422079'),
#  ('POL', 'Poland', '383807'),
#  ('ARE', 'United Arab Emirates', '375013'),
#  ('CAN', 'Canada', '233581'),
#  ('CHE', 'Switzerland', '223895'),
#  ('CYP', 'Cyprus', '207526'),
#  ('HRV', 'Croatia', '175919'),
#  ('ROU', 'Romania', '172180'),
#  ('DNK', 'Denmark', '163288'),
#  ('BGR', 'Bulgaria', '140800'),
#  ('IND', 'India', '130743'),
#  ('HUN', 'Hungary', '124460'),
#  ('SWE', 'Sweden', '124270'),
#  ('QAT', 'Qatar', '119105'),
#  ('NOR', 'Norway', '113565'),
#  ('CZE', 'Czech Republic', '104123')]

# %%
#2. Investigate which are the top 25 UK airports people use to travel 
sorted_airports = add_to_airports(travel_list[1])
top_airports = sorted_airports [:25]

# create dictionary for all airports and give each a start count of 0
airports = dict.fromkeys(sorted_airports, 0) 

# Add each airport instance passenger count 
for i in travel_list[1]:
    airports[i[1]] += int(i[4])

# combine airport and total passenger count
passenger_count = []
for key, value in airports.items():
    passenger_count.append((key, value))

# sort the list of pairs from most passengers to least 
passenger_count.sort(key = lambda x:x[1], reverse = True)

# store the top 25 most travelled to airports
top_airports = passenger_count [:25]

# output the list
top_airports
# Out:
# [('LONDON HEATHROW airport', 3648223),
#  ('LONDON GATWICK airport', 2337904),
#  ('MANCHESTER airport', 1516365),
#  ('LONDON STANSTED airport', 1372224),
#  ('LONDON LUTON airport', 892184),
#  ('BIRMINGHAM airport', 641923),
#  ('EDINBURGH airport', 494420),
#  ('BRISTOL airport', 438491),
#  ('GLASGOW airport', 285216),
#  ('EAST MIDLANDS airport', 283101),
#  ('NEWCASTLE airport', 247822),
#  ('LEEDS BRADFORD airport', 238488),
#  ('LIVERPOOL airport', 218280),
#  ('LONDON/CITY airport', 184703),
#  ('BELFAST/ALDERGROVE airport', 156932),
#  ('SOUTHEND airport', 111425),
#  ('CARDIFF airport', 93162),
#  ('DONCASTER SHEFFIELD airport', 81437),
#  ('ABERDEEN/DYCE airport', 48726),
#  ('BOURNEMOUTH airport', 47806),
#  ('PRESTWICK airport', 41029),
#  ('SOUTHAMPTON airport', 37805),
#  ('EXETER airport', 35727),
#  ('NORWICH airport', 20162),
#  ('BELFAST/CITY airport', 11399)]

# %%
#3. Calculate the disease prevalence to the top 25 countries travelling into the UK. 
# Use sorted countries to get population, number of cases. prevalence = cases/(0.5*population)
# prevalence should be a number between 0 and 1.

prevalenceCountries = calculatePrevalence(matchedCountries, who_covid_list, world_pop_list)
sortedPrevalence = sortList(prevalenceCountries)
sortedPrevalence
# Out:
# [('CZE', 'Czech Republic', '0.01390104249881478'),
#  ('USA', 'United States of America', '0.00903870102236734'),
#  ('IRL', 'Ireland', '0.00854755552387244'),
#  ('CYP', 'Cyprus', '0.00700868590038257'),
#  ('PRT', 'Portugal', '0.0068565259634260425'),
#  ('NLD', 'Netherlands', '0.006714610999136731'),
#  ('CHE', 'Switzerland', '0.005423229344967348'),
#  ('DNK', 'Denmark', '0.005165910995507408'),
#  ('HRV', 'Croatia', '0.003797073369405693'),
#  ('ITA', 'Italy', '0.0036375679424567827'),
#  ('POL', 'Poland', '0.003271574302914467'),
#  ('SWE', 'Sweden', '0.003155477156010858'),
#  ('FRA', 'France', '0.0029439200842130277'),
#  ('DEU', 'Germany', '0.0029285802761584074'),
#  ('CAN', 'Canada', '0.00277461641431488'),
#  ('ROU', 'Romania', '0.0026125796489817827'),
#  ('HUN', 'Hungary', '0.002515436550907933'),
#  ('ARE', 'United Arab Emirates', '0.0024933263582208286'),
#  ('TUR', 'Turkey', '0.0022013997380359923'),
#  ('BGR', 'Bulgaria', '0.0017347766298790592'),
#  ('NOR', 'Norway', '0.0013495065059826708'),
#  ('QAT', 'Qatar', '0.0009885274585368614'),
#  ('GRC', 'Greece', '0.0008816993560620525'),
#  ('ESP', 'Spain', '0.0003301052996123733'),
#  ('IND', 'India', '0.00018852114009768164')]

# %%
#4.	Calculate the number of infected people arriving into each airport from top 25 countries
#by multiplying number of passengers from each country by prevalence in that country


airport_list = airpotPrevalence(travel_list, sortedPrevalence)
infected_airports = sortList(airport_list)
infected_airports
# Out:
# [('LONDON HEATHROW airport', 'USA', 7018.903853208112),
#  ('LONDON GATWICK airport', 'USA', 1493.6543826472252),
#  ('MANCHESTER airport', 'USA', 1003.2686973797076),
#  ('LONDON HEATHROW airport', 'IRL', 990.8411838828172),
#  ('LONDON GATWICK airport', 'ITA', 861.9944753239838),
#  ('LONDON HEATHROW airport', 'DEU', 761.6973726063163),
#  ('LONDON GATWICK airport', 'PRT', 687.2364538401557),
#  ('LONDON STANSTED airport', 'ITA', 681.3273883259827),
#  ('LONDON STANSTED airport', 'IRL', 671.5301521775144),
#  ('LONDON GATWICK airport', 'IRL', 627.5102412295713),
#  ('LONDON HEATHROW airport', 'CHE', 524.0520748335398),
#  ('LONDON STANSTED airport', 'PRT', 481.21841821709336),
#  ('LONDON GATWICK airport', 'FRA', 475.3076732765302),
#  ('MANCHESTER airport', 'IRL', 466.29479649381324),
#  ('LONDON HEATHROW airport', 'ITA', 461.59645919393836),
#  ('MANCHESTER airport', 'PRT', 454.48482348569524),
#  ('LONDON HEATHROW airport', 'NLD', 453.4846830486974),
#  ('LONDON HEATHROW airport', 'ARE', 443.5901857174258),
#  ('LONDON HEATHROW airport', 'FRA', 431.9967209975881),
#  ('BIRMINGHAM airport', 'IRL', 417.41132645278674),
#  ('LONDON STANSTED airport', 'CZE', 379.24824145266484),
#  ('LONDON HEATHROW airport', 'CAN', 365.3698132862263),
#  ('LONDON HEATHROW airport', 'PRT', 361.2017877532839),
#  ('MANCHESTER airport', 'NLD', 325.6989211241263),
#  ('LONDON LUTON airport', 'POL', 315.3797628009546),
#  ('LONDON LUTON airport', 'PRT', 310.6074826691632),
#  ('LONDON STANSTED airport', 'FRA', 310.4069336794216),
#  ('LONDON LUTON airport', 'IRL', 306.29310464244503),
#  ('MANCHESTER airport', 'ITA', 298.32422209676565),
#  ('EDINBURGH airport', 'IRL', 297.22414823161637),
#  ('LONDON STANSTED airport', 'DEU', 291.0159506221371),
#  ('LONDON GATWICK airport', 'NLD', 288.4328300789174),
#  ('LONDON HEATHROW airport', 'CZE', 286.2363660930951),
#  ('LONDON GATWICK airport', 'CYP', 285.80019364580045),
#  ('LONDON STANSTED airport', 'POL', 282.95518988476937),
#  ('LONDON LUTON airport', 'ROU', 267.8181523967715),
#  ('MANCHESTER airport', 'DEU', 252.60469172004343),
#  ('EDINBURGH airport', 'USA', 247.85925943535722),
#  ('LONDON HEATHROW airport', 'DNK', 237.56474895039918),
#  ('EDINBURGH airport', 'NLD', 230.43202026837434),
#  ('MANCHESTER airport', 'CYP', 226.9062060248857),
#  ('BRISTOL airport', 'IRL', 218.22764007998728),
#  ('LONDON LUTON airport', 'NLD', 217.2109512110741),
#  ('GLASGOW airport', 'IRL', 211.09897877307765),
#  ('LIVERPOOL airport', 'IRL', 209.63734677849547),
#  ('LONDON STANSTED airport', 'NLD', 203.7750146018015),
#  ('LONDON/CITY airport', 'NLD', 194.5625683109859),
#  ('LONDON LUTON airport', 'ITA', 191.26332241437763),
#  ('BIRMINGHAM airport', 'NLD', 189.37888861965237),
#  ('LONDON GATWICK airport', 'HRV', 185.44146921503523),
#  ('MANCHESTER airport', 'FRA', 183.38855772596634),
#  ('LONDON GATWICK airport', 'CHE', 182.35608672452707),
#  ('LONDON GATWICK airport', 'TUR', 181.8928547549619),
#  ('BRISTOL airport', 'PRT', 176.85723070061135),
#  ('LONDON STANSTED airport', 'DNK', 175.46533287340463),
#  ('LONDON HEATHROW airport', 'SWE', 174.40637788987615),
#  ('LONDON GATWICK airport', 'ESP', 172.59159463873402),
#  ('LONDON GATWICK airport', 'CAN', 171.7376575804338),
#  ('LONDON GATWICK airport', 'CZE', 170.9133175229277),
#  ('MANCHESTER airport', 'TUR', 170.10876195725524),
#  ('MANCHESTER airport', 'ARE', 169.90772468095835),
#  ('LONDON GATWICK airport', 'GRC', 163.64692728254118),
#  ('GLASGOW airport', 'USA', 162.88643112408184),
#  ('BIRMINGHAM airport', 'PRT', 162.47909575530693),
#  ('LONDON LUTON airport', 'FRA', 157.59392994809178),
#  ('LONDON/CITY airport', 'IRL', 157.51435319392132),
#  ('LONDON GATWICK airport', 'DNK', 156.45478040993737),
#  ('LONDON LUTON airport', 'CYP', 155.1793145203705),
#  ('EDINBURGH airport', 'DEU', 148.88902123989342),
#  ('LONDON/CITY airport', 'CHE', 146.6278517998822),
#  ('EAST MIDLANDS airport', 'PRT', 141.26500442446675),
#  ('BRISTOL airport', 'ITA', 139.81719900421135),
#  ('GLASGOW airport', 'NLD', 139.12673990211306),
#  ('LONDON STANSTED airport', 'USA', 137.06286230317835),
#  ('BRISTOL airport', 'FRA', 133.92775639110326),
#  ('BRISTOL airport', 'NLD', 133.00301467090037),
#  ('LONDON STANSTED airport', 'CYP', 132.68143278014244),
#  ('LONDON STANSTED airport', 'TUR', 128.45387611413818),
#  ('BIRMINGHAM airport', 'DEU', 128.1693157860727),
#  ('EDINBURGH airport', 'ITA', 119.26857769727299),
#  ('MANCHESTER airport', 'ESP', 118.52463793112224),
#  ('BIRMINGHAM airport', 'CYP', 118.4608090882662),
#  ('LONDON HEATHROW airport', 'TUR', 117.90476856946971),
#  ('LONDON GATWICK airport', 'ARE', 117.83709701587458),
#  ('LEEDS BRADFORD airport', 'IRL', 117.56307867534154),
#  ('MANCHESTER airport', 'CZE', 116.58804343755956),
#  ('EAST MIDLANDS airport', 'IRL', 115.10138268446629),
#  ('MANCHESTER airport', 'GRC', 113.16787574927656),
#  ('LEEDS BRADFORD airport', 'PRT', 112.06991687219866),
#  ('LONDON GATWICK airport', 'DEU', 111.19819308573473),
#  ('EDINBURGH airport', 'FRA', 110.94751621373638),
#  ('BELFAST/ALDERGROVE airport', 'PRT', 110.06781129087825),
#  ('LONDON LUTON airport', 'CHE', 103.51860173673674),
#  ('LONDON HEATHROW airport', 'CYP', 102.55109209439777),
#  ('LIVERPOOL airport', 'PRT', 102.01139328385266),
#  ('NEWCASTLE airport', 'NLD', 101.5853498059396),
#  ('MANCHESTER airport', 'HRV', 99.7111466805935),
#  ('MANCHESTER airport', 'DNK', 99.62459354836037),
#  ('EDINBURGH airport', 'PRT', 97.48608614799147),
#  ('LONDON STANSTED airport', 'ESP', 94.49330222464108),
#  ('ABERDEEN/DYCE airport', 'NLD', 94.4208598698607),
#  ('EDINBURGH airport', 'CZE', 91.06572940973562),
#  ('MANCHESTER airport', 'CHE', 90.88790059230779),
#  ('LONDON STANSTED airport', 'HRV', 90.7044886483632),
#  ('BIRMINGHAM airport', 'CZE', 89.53661473486599),
#  ('NEWCASTLE airport', 'PRT', 88.97713742737976),
#  ('LONDON LUTON airport', 'HUN', 88.82006461255911),
#  ('NEWCASTLE airport', 'IRL', 85.96276590358514),
#  ('LONDON GATWICK airport', 'SWE', 85.74693623743906),
#  ('BIRMINGHAM airport', 'FRA', 85.38840204259887),
#  ('SOUTHEND airport', 'IRL', 84.90286901862495),
#  ('LONDON HEATHROW airport', 'POL', 83.98458393011728),
#  ('BIRMINGHAM airport', 'ARE', 83.39428670341205),
#  ('LONDON LUTON airport', 'CZE', 81.50181217055106),
#  ('EDINBURGH airport', 'DNK', 79.48270657687699),
#  ('LONDON/CITY airport', 'DEU', 78.42737979552216),
#  ('BIRMINGHAM airport', 'ITA', 77.61114962025792),
#  ('SOUTHEND airport', 'PRT', 77.19076929625038),
#  ('BRISTOL airport', 'CYP', 76.40869368597077),
#  ('BIRMINGHAM airport', 'TUR', 73.40567426481016),
#  ('SOUTHEND airport', 'NLD', 71.77247696977251),
#  ('LONDON/CITY airport', 'ITA', 69.12470361050624),
#  ('LIVERPOOL airport', 'POL', 68.75867712435335),
#  ('LEEDS BRADFORD airport', 'NLD', 68.63003902217653),
#  ('LONDON HEATHROW airport', 'QAT', 66.96976973349675),
#  ('LIVERPOOL airport', 'NLD', 66.05162839850803),
#  ('BIRMINGHAM airport', 'ESP', 63.127356866072596),
#  ('DONCASTER SHEFFIELD airport', 'POL', 62.094480269316584),
#  ('LONDON/CITY airport', 'PRT', 61.54417704771216),
#  ('LONDON HEATHROW airport', 'GRC', 61.04886341373651),
#  ('BRISTOL airport', 'CZE', 59.09333166246163),
#  ('LONDON LUTON airport', 'HRV', 58.60403038340746),
#  ('LONDON STANSTED airport', 'GRC', 57.75395292013262),
#  ('BRISTOL airport', 'POL', 57.62550977153543),
#  ('GLASGOW airport', 'PRT', 57.42340494369311),
#  ('NEWCASTLE airport', 'CYP', 57.408146210033635),
#  ('LONDON LUTON airport', 'BGR', 57.216402806671134),
#  ('LONDON STANSTED airport', 'SWE', 56.959518143152),
#  ('EDINBURGH airport', 'CHE', 56.56970529735441),
#  ('EDINBURGH airport', 'POL', 56.54261867727074),
#  ('MANCHESTER airport', 'POL', 56.08786984916563),
#  ('EAST MIDLANDS airport', 'CYP', 56.0554698312598),
#  ('GLASGOW airport', 'ARE', 55.40919165874147),
#  ('SOUTHAMPTON airport', 'IRL', 52.89227358172266),
#  ('LEEDS BRADFORD airport', 'CYP', 51.597945598616484),
#  ('INVERNESS airport', 'NLD', 51.59507091736664),
#  ('BIRMINGHAM airport', 'POL', 51.35063025854548),
#  ('LONDON HEATHROW airport', 'HUN', 50.90740491727475),
#  ('NORWICH airport', 'NLD', 50.48716010250908),
#  ('LONDON GATWICK airport', 'NOR', 50.051846800391274),
#  ('LIVERPOOL airport', 'FRA', 49.622716939494794),
#  ('CARDIFF airport', 'IRL', 49.473251372173685),
#  ('MANCHESTER airport', 'CAN', 49.282736751060895),
#  ('BIRMINGHAM airport', 'GRC', 48.222782881101836),
#  ('LONDON STANSTED airport', 'HUN', 47.80335621345436),
#  ('BRISTOL airport', 'ESP', 47.515686931504625),
#  ('SOUTHAMPTON airport', 'NLD', 47.48572898589496),
#  ('EAST MIDLANDS airport', 'ESP', 46.949886447969014),
#  ('LONDON HEATHROW airport', 'ESP', 46.04935919062646),
#  ('LONDON HEATHROW airport', 'HRV', 45.997746796980564),
#  ('EAST MIDLANDS airport', 'ITA', 45.02945355967251),
#  ('LONDON HEATHROW airport', 'NOR', 44.74153869934947),
#  ('LONDON LUTON airport', 'ESP', 44.096456238119664),
#  ('LONDON GATWICK airport', 'POL', 43.97323020547335),
#  ('LONDON LUTON airport', 'DEU', 43.81741809188209),
#  ('GLASGOW airport', 'CYP', 43.62206104398112),
#  ('CARDIFF airport', 'NLD', 43.3428139994276),
#  ('BELFAST/ALDERGROVE airport', 'USA', 42.81632674295409),
#  ('LIVERPOOL airport', 'ITA', 42.27945219517519),
#  ('BRISTOL airport', 'HRV', 41.17166654446593),
#  ('GLASGOW airport', 'CAN', 41.08651986317474),
#  ('BELFAST/ALDERGROVE airport', 'NLD', 40.91883942873924),
#  ('NEWCASTLE airport', 'TUR', 40.63783916414442),
#  ('EDINBURGH airport', 'CYP', 39.42385818965196),
#  ('HUMBERSIDE airport', 'NLD', 38.622442467034475),
#  ('SOUTHAMPTON airport', 'FRA', 38.26212933451672),
#  ('LONDON GATWICK airport', 'HUN', 37.74664088292444),
#  ('BRISTOL airport', 'CHE', 37.29012497599548),
#  ('GLASGOW airport', 'DEU', 36.982111727328366),
#  ('LONDON LUTON airport', 'TUR', 36.77438262389125),
#  ('BIRMINGHAM airport', 'CHE', 36.66103037197927),
#  ('EAST MIDLANDS airport', 'POL', 36.33410420816807),
#  ('LEEDS BRADFORD airport', 'ESP', 36.290456218185874),
#  ('BRISTOL airport', 'TUR', 35.634057559588605),
#  ('LEEDS BRADFORD airport', 'POL', 35.52929692965111),
#  ('NEWCASTLE airport', 'ESP', 35.4909411825247),
#  ('LONDON HEATHROW airport', 'ROU', 35.42135488089501),
#  ('EDINBURGH airport', 'SWE', 35.3949872589738),
#  ('SOUTHEND airport', 'CZE', 33.64052284713177),
#  ('MANCHESTER airport', 'BGR', 33.031881809527164),
#  ('BRISTOL airport', 'GRC', 33.00200689740262),
#  ('EDINBURGH airport', 'ESP', 32.507449484628076),
#  ('LIVERPOOL airport', 'CZE', 32.09750712976333),
#  ('LONDON GATWICK airport', 'ROU', 32.08509066914527),
#  ('BELFAST/ALDERGROVE airport', 'POL', 31.430014328099286),
#  ('SOUTHEND airport', 'FRA', 31.27915089476342),
#  ('LONDON LUTON airport', 'GRC', 30.74132974845952),
#  ('LEEDS BRADFORD airport', 'TUR', 30.46296957494206),
#  ('MANCHESTER airport', 'SWE', 30.065386342471456),
#  ('LONDON/CITY airport', 'CZE', 30.026251797439926),
#  ('EAST MIDLANDS airport', 'GRC', 29.13928201849477),
#  ('LONDON STANSTED airport', 'ROU', 28.88729317879157),
#  ('LONDON GATWICK airport', 'BGR', 28.831987588589964),
#  ('BELFAST/CITY airport', 'PRT', 28.680848105011137),
#  ('NEWCASTLE airport', 'ARE', 28.226947701418002),
#  ('BIRMINGHAM airport', 'HRV', 28.09454586023272),
#  ('LONDON STANSTED airport', 'BGR', 27.93857762420225),
#  ('BELFAST/ALDERGROVE airport', 'ESP', 27.77968138357966),
#  ('GLASGOW airport', 'ITA', 27.772831240657535),
#  ('DURHAM TEES VALLEY airport', 'NLD', 27.35532521048304),
#  ('CARDIFF airport', 'PRT', 27.23412112672824),
#  ('LEEDS BRADFORD airport', 'ITA', 27.17990766603708),
#  ('GLASGOW airport', 'ESP', 27.046517513140582),
#  ('PRESTWICK airport', 'PRT', 27.021568821862033),
#  ('NEWCASTLE airport', 'FRA', 26.61009364120156),
#  ('GLASGOW airport', 'FRA', 26.339252993453957),
#  ('LIVERPOOL airport', 'CHE', 25.863380746149282),
#  ('NEWCASTLE airport', 'ITA', 25.644853994320318),
#  ('LIVERPOOL airport', 'ROU', 25.496164794413218),
#  ('EAST MIDLANDS airport', 'FRA', 25.45607696819005),
#  ('BOURNEMOUTH airport', 'IRL', 25.223836350947572),
#  ('LIVERPOOL airport', 'ESP', 24.93483391152023),
#  ('EDINBURGH airport', 'TUR', 24.384904898224686),
#  ('LONDON STANSTED airport', 'ARE', 24.04065274596523),
#  ('GLASGOW airport', 'TUR', 23.94242355087945),
#  ('LONDON LUTON airport', 'DNK', 23.92333382019481),
#  ('LONDON HEATHROW airport', 'IND', 23.478234266625176),
#  ('LEEDS BRADFORD airport', 'FRA', 23.348230187893524),
#  ('BELFAST/ALDERGROVE airport', 'FRA', 23.33645450755667),
#  ('GLASGOW airport', 'POL', 23.21509125348106),
#  ('CARDIFF airport', 'CYP', 23.002507125055597),
#  ('DONCASTER SHEFFIELD airport', 'ROU', 22.67457877351289),
#  ('GLASGOW airport', 'CZE', 22.005350275623798),
#  ('MANCHESTER airport', 'HUN', 21.937122160468082),
#  ('LONDON STANSTED airport', 'NOR', 21.601550641264613),
#  ('SOUTHEND airport', 'ITA', 21.58532817053855),
#  ('LONDON/CITY airport', 'FRA', 21.181505005912733),
#  ('EDINBURGH airport', 'HRV', 21.16488696106733),
#  ('BOURNEMOUTH airport', 'PRT', 21.10438691542536),
#  ('DONCASTER SHEFFIELD airport', 'IRL', 20.24915903605381),
#  ('LIVERPOOL airport', 'CYP', 20.241084880304864),
#  ('BIRMINGHAM airport', 'DNK', 20.074730128541788),
#  ('NEWCASTLE airport', 'GRC', 20.068359043328375),
#  ('EAST MIDLANDS airport', 'TUR', 20.052550213769855),
#  ('BIRMINGHAM airport', 'ROU', 20.022810429796383),
#  ('ABERDEEN/DYCE airport', 'IRL', 20.009827481385383),
#  ('BELFAST/ALDERGROVE airport', 'ITA', 19.711980680173305),
#  ('BOURNEMOUTH airport', 'CZE', 19.6560740933241),
#  ('BRISTOL airport', 'DEU', 18.965485868401846),
#  ('NEWCASTLE airport', 'USA', 18.55645319892015),
#  ('LEEDS BRADFORD airport', 'GRC', 18.50686948374248),
#  ('NEWQUAY airport', 'IRL', 18.351601709754128),
#  ('DONCASTER SHEFFIELD airport', 'NLD', 18.32417341664414),
#  ('BELFAST/CITY airport', 'NLD', 18.257027306652773),
#  ('EXETER airport', 'IRL', 18.2062932658483),
#  ('BIRMINGHAM airport', 'BGR', 18.098924579528227),
#  ('LEEDS BRADFORD airport', 'CZE', 17.835037525979363),
#  ('LEEDS BRADFORD airport', 'HRV', 17.819665322620917),
#  ('DONCASTER SHEFFIELD airport', 'CYP', 17.500688693255277),
#  ('EAST MIDLANDS airport', 'CZE', 17.41800625101492),
#  ('BOURNEMOUTH airport', 'CYP', 16.91195907762314),
#  ('EXETER airport', 'NLD', 16.880532051829743),
#  ('NEWCASTLE airport', 'POL', 15.700285079686529),
#  ('LONDON/CITY airport', 'POL', 15.461460155573771),
#  ('EAST MIDLANDS airport', 'NLD', 15.356315355025703),
#  ('ABERDEEN/DYCE airport', 'DNK', 15.234271525751348),
#  ('LONDON GATWICK airport', 'QAT', 15.226288443843275),
#  ('MANCHESTER airport', 'QAT', 15.221345806550591),
#  ('MANCHESTER airport', 'NOR', 15.133365958089671),
#  ('LONDON HEATHROW airport', 'BGR', 15.030104721272169),
#  ('SOUTHEND airport', 'ESP', 14.751745629077737),
#  ('EAST MIDLANDS airport', 'HRV', 14.341546116245302),
#  ('EXETER airport', 'FRA', 13.945349438917113),
#  ('CARDIFF airport', 'ITA', 13.71363114306207),
#  ('BIRMINGHAM airport', 'USA', 13.268813100835256),
#  ('GLASGOW airport', 'GRC', 13.191104066044367),
#  ('CARDIFF airport', 'ESP', 13.04246038768487),
#  ('BELFAST/ALDERGROVE airport', 'CYP', 12.783843082297809),
#  ('EDINBURGH airport', 'ARE', 12.623711351672055),
#  ('CARDIFF airport', 'TUR', 12.51275611099658),
#  ('EXETER airport', 'PRT', 12.259468422605764),
#  ('EDINBURGH airport', 'CAN', 12.24160761995725),
#  ('BELFAST/ALDERGROVE airport', 'HRV', 12.207590882639302),
#  ('DONCASTER SHEFFIELD airport', 'PRT', 12.204616214898357),
#  ('EDINBURGH airport', 'GRC', 12.158634120095703),
#  ('SOUTHEND airport', 'HRV', 11.83168061906814),
#  ('EXETER airport', 'CYP', 11.80963574214463),
#  ('BRISTOL airport', 'DNK', 11.426995122062387),
#  ('CARDIFF airport', 'FRA', 11.316428803714878),
#  ('ABERDEEN/DYCE airport', 'FRA', 11.128017918325245),
#  ('PRESTWICK airport', 'ITA', 11.09094465655073),
#  ('ABERDEEN/DYCE airport', 'PRT', 10.943015437627963),
#  ('NEWQUAY airport', 'PRT', 10.853880600103425),
#  ('GLASGOW airport', 'HRV', 10.77229714900395),
#  ('BRISTOL airport', 'USA', 10.701822010482932),
#  ('ABERDEEN/DYCE airport', 'NOR', 10.624664721601567),
#  ('PRESTWICK airport', 'ESP', 10.60859401364284),
#  ('EAST MIDLANDS airport', 'USA', 10.566241495147422),
#  ('SOUTHAMPTON airport', 'PRT', 10.332784626883045),
#  ('NEWCASTLE airport', 'HRV', 10.309054197936456),
#  ('DONCASTER SHEFFIELD airport', 'HUN', 10.29316636631526),
#  ('LONDON/CITY airport', 'HUN', 10.290650929764354),
#  ('BELFAST/ALDERGROVE airport', 'TUR', 10.166063990250212),
#  ('EDINBURGH airport', 'HUN', 10.11205493464989),
#  ('BOURNEMOUTH airport', 'ESP', 10.057318163290176),
#  ('EAST MIDLANDS airport', 'HUN', 9.427856192802933),
#  ('SOUTHEND airport', 'DNK', 9.246980681958261),
#  ('CARDIFF airport', 'GRC', 9.167909904333222),
#  ('NEWCASTLE airport', 'CHE', 8.736822474742398),
#  ('EDINBURGH airport', 'NOR', 8.73130709370788),
#  ('LONDON STANSTED airport', 'CAN', 8.379341571230936),
#  ('ABERDEEN/DYCE airport', 'POL', 8.237824094738627),
#  ('INVERNESS airport', 'IRL', 8.214200858441416),
#  ('NEWCASTLE airport', 'BGR', 7.943542188216212),
#  ('EDINBURGH airport', 'QAT', 7.928978744924165),
#  ('LIVERPOOL airport', 'DEU', 7.810523596514472),
#  ('EDINBURGH airport', 'BGR', 7.2583054194139836),
#  ('GLASGOW airport', 'ROU', 7.119279543475358),
#  ('DONCASTER SHEFFIELD airport', 'HRV', 6.975223779598258),
#  ('EAST MIDLANDS airport', 'BGR', 6.91481964669793),
#  ('LIVERPOOL airport', 'TUR', 6.815533588959432),
#  ('LIVERPOOL airport', 'DNK', 6.782841137101228),
#  ('LIVERPOOL airport', 'BGR', 6.777772292937485),
#  ('DONCASTER SHEFFIELD airport', 'FRA', 6.7739601137741765),
#  ('LONDON/CITY airport', 'ESP', 6.754944745967995),
#  ('BIRMINGHAM airport', 'QAT', 6.474854853416442),
#  ('BRISTOL airport', 'HUN', 6.439517570324308),
#  ('BRISTOL airport', 'BGR', 6.309382602870138),
#  ('NORWICH airport', 'CYP', 6.139608848735132),
#  ('LIVERPOOL airport', 'HUN', 6.137665184215356),
#  ('DONCASTER SHEFFIELD airport', 'ESP', 6.018149717233178),
#  ('SOUTHEND airport', 'ROU', 5.990645135115227),
#  ('BIRMINGHAM airport', 'HUN', 5.98673899116088),
#  ('DONCASTER SHEFFIELD airport', 'GRC', 5.921492875312745),
#  ('CARDIFF airport', 'QAT', 5.917325366801652),
#  ('BELFAST/ALDERGROVE airport', 'BGR', 5.7160889954515),
#  ('PRESTWICK airport', 'POL', 5.597663632286653),
#  ('BOURNEMOUTH airport', 'POL', 5.394826025505957),
#  ('DONCASTER SHEFFIELD airport', 'TUR', 5.281157971548345),
#  ('GLASGOW airport', 'BGR', 5.173103910299354),
#  ('EXETER airport', 'ITA', 5.052581872072471),
#  ('EXETER airport', 'ESP', 5.021891923003035),
#  ('LEEDS BRADFORD airport', 'DEU', 4.996157951126243),
#  ('BELFAST/ALDERGROVE airport', 'DEU', 4.735514306548144),
#  ('LONDON/CITY airport', 'HRV', 4.6931826845854365),
#  ('EAST MIDLANDS airport', 'DEU', 4.536370847769373),
#  ('DONCASTER SHEFFIELD airport', 'BGR', 4.477458481717852),
#  ('LEEDS BRADFORD airport', 'BGR', 4.387250096964141),
#  ('NEWCASTLE airport', 'DEU', 4.387013253685295),
#  ('LONDON LUTON airport', 'SWE', 4.323003703734876),
#  ('BRISTOL airport', 'ROU', 4.318594159766887),
#  ('LIVERPOOL airport', 'HRV', 4.2868958340590275),
#  ('BRISTOL airport', 'SWE', 4.218872957586517),
#  ('LIVERPOOL airport', 'GRC', 4.084031417279427),
#  ('GLASGOW airport', 'HUN', 4.03979110075814),
#  ('SOUTHAMPTON airport', 'DEU', 3.900868927842999),
#  ('LONDON/CITY airport', 'GRC', 3.883885663453341),
#  ('BELFAST/ALDERGROVE airport', 'GRC', 3.4465627828465633),
#  ('EXETER airport', 'TUR', 3.41657239343186),
#  ('LONDON/CITY airport', 'DNK', 3.4095012570348895),
#  ('NORWICH airport', 'TUR', 3.3219122046963125),
#  ('CARDIFF airport', 'HRV', 3.2237152906254334),
#  ('LEEDS BRADFORD airport', 'HUN', 3.1292030693294683),
#  ('BOURNEMOUTH airport', 'GRC', 3.080657550080811),
#  ('DONCASTER SHEFFIELD airport', 'ITA', 2.7572765003822415),
#  ('EXETER airport', 'GRC', 2.7306229057241764),
#  ('SOUTHAMPTON airport', 'ESP', 2.674183032159836),
#  ('HUMBERSIDE airport', 'BGR', 2.54491731603258),
#  ('ABERDEEN/DYCE airport', 'ESP', 2.46192532450908),
#  ('CARDIFF airport', 'BGR', 2.461648037798385),
#  ('NORWICH airport', 'ESP', 2.38402047380056),
#  ('NEWQUAY airport', 'DNK', 2.376319057933408),
#  ('CARDIFF airport', 'DEU', 2.2257210098803895),
#  ('SOUTHAMPTON airport', 'ITA', 2.2116413090137237),
#  ('NEWQUAY airport', 'DEU', 2.190578046566489),
#  ('ABERDEEN/DYCE airport', 'TUR', 2.0274891587311488),
#  ('NORWICH airport', 'GRC', 2.0235000221624104),
#  ('BOURNEMOUTH airport', 'TUR', 1.9680513658041772),
#  ('INVERNESS airport', 'CHE', 1.6703546382499432),
#  ('GLASGOW airport', 'DNK', 1.5136119216836708),
#  ('BELFAST/CITY airport', 'ESP', 1.4834932164580057),
#  ('DURHAM TEES VALLEY airport', 'BGR', 1.4832340185465955),
#  ('ABERDEEN/DYCE airport', 'BGR', 1.4398646027996191),
#  ('ABERDEEN/DYCE airport', 'GRC', 1.4362882510250834),
#  ('SOUTHEND airport', 'GRC', 1.2643568765929831),
#  ('NORWICH airport', 'BGR', 1.2212827474348578),
#  ('BIRMINGHAM airport', 'IND', 1.1695851531660169),
#  ('LONDON/CITY airport', 'USA', 1.1298376277959175),
#  ('BELFAST/ALDERGROVE airport', 'DNK', 0.9505276231733631),
#  ('NEWCASTLE airport', 'NOR', 0.7948593320237931),
#  ('GLASGOW airport', 'SWE', 0.7289152230385082),
#  ('ABERDEEN/DYCE airport', 'HRV', 0.6265171059519393),
#  ('INVERNESS airport', 'NOR', 0.5883848366084444),
#  ('BELFAST/ALDERGROVE airport', 'CZE', 0.5560416999525912),
#  ('PRESTWICK airport', 'FRA', 0.5505130557478362),
#  ('NEWQUAY airport', 'ESP', 0.48360426393212685),
#  ('GLASGOW airport', 'NOR', 0.39000738022899184),
#  ('LIVERPOOL airport', 'NOR', 0.30228945734011825),
#  ('BELFAST/ALDERGROVE airport', 'SWE', 0.2871484211969881),
#  ('SOUTHEND airport', 'DEU', 0.2313578418165142),
#  ('HUMBERSIDE airport', 'ESP', 0.23041349912943657),
#  ('SUMBURGH airport', 'NOR', 0.21457153445124466),
#  ('NORWICH airport', 'FRA', 0.09420544269481688),
#  ('KIRKWALL airport', 'NOR', 0.07422285782904689),
#  ('PRESTWICK airport', 'USA', 0.03615480408946936),
#  ('BELFAST/CITY airport', 'USA', 0.02711610306710202),
#  ('DUNDEE airport', 'NOR', 0.008097039035896024),
#  ('EAST MIDLANDS airport', 'DNK', 0.0),
#  ('BOURNEMOUTH airport', 'NOR', 0.0),
#  ('EAST MIDLANDS airport', 'NOR', 0.0),
#  ('STORNOWAY airport', 'NOR', 0.0),
#  ('LONDON STANSTED airport', 'QAT', 0.0)]

# %%
#5.a.Aggregate to get the total number of infected people arriving from the 
# top 25 countries arriving at each UK airport

infected_arriving = airports_infected(airport_list)
infected_arriving
# Out:
# [('LONDON HEATHROW airport', 13191),
#  ('LONDON GATWICK airport', 6614),
#  ('MANCHESTER airport', 4400),
#  ('LONDON STANSTED airport', 4322),
#  ('LONDON LUTON airport', 2485),
#  ('EDINBURGH airport', 1749),
#  ('BIRMINGHAM airport', 1730),
#  ('BRISTOL airport', 1243),
#  ('GLASGOW airport', 932),
#  ('LONDON/CITY airport', 798),
#  ('LIVERPOOL airport', 701),
#  ('EAST MIDLANDS airport', 588),
#  ('NEWCASTLE airport', 567),
#  ('LEEDS BRADFORD airport', 562),
#  ('SOUTHEND airport', 357),
#  ('BELFAST/ALDERGROVE airport', 338),
#  ('CARDIFF airport', 212),
#  ('DONCASTER SHEFFIELD airport', 195),
#  ('ABERDEEN/DYCE airport', 174),
#  ('SOUTHAMPTON airport', 154),
#  ('BOURNEMOUTH airport', 100),
#  ('EXETER airport', 85),
#  ('NORWICH airport', 64),
#  ('INVERNESS airport', 60),
#  ('PRESTWICK airport', 53),
#  ('BELFAST/CITY airport', 47),
#  ('HUMBERSIDE airport', 40),
#  ('NEWQUAY airport', 32),
#  ('DURHAM TEES VALLEY airport', 28),
#  ('KIRKWALL airport', 0),
#  ('SUMBURGH airport', 0),
#  ('DUNDEE airport', 0),
#  ('STORNOWAY airport', 0)]

# %%
#5.b. Calculate the number of infected people arriving from each top 25 countries 

country_arriving = countries_infected(airport_list)

matchedArrivals = matchData(country_arriving, country_code_list)
matchedArrivals
# Out:
# [('USA', 'United States of America', '10154'),
#  ('IRL', 'Ireland', '5180'),
#  ('PRT', 'Portugal', '3633'),
#  ('ITA', 'Italy', '3135'),
#  ('NLD', 'Netherlands', '3134'),
#  ('FRA', 'France', '2187'),
#  ('DEU', 'Germany', '1896'),
#  ('CYP', 'Cyprus', '1445'),
#  ('CZE', 'Czech Republic', '1441'),
#  ('POL', 'Poland', '1246'),
#  ('CHE', 'Switzerland', '1208'),
#  ('ARE', 'United Arab Emirates', '931'),
#  ('TUR', 'Turkey', '919'),
#  ('ESP', 'Spain', '882'),
#  ('DNK', 'Denmark', '836'),
#  ('HRV', 'Croatia', '658'),
#  ('CAN', 'Canada', '646'),
#  ('GRC', 'Greece', '630'),
#  ('ROU', 'Romania', '445'),
#  ('SWE', 'Sweden', '388'),
#  ('HUN', 'Hungary', '306'),
#  ('BGR', 'Bulgaria', '235'),
#  ('NOR', 'Norway', '148'),
#  ('QAT', 'Qatar', '114'),
#  ('IND', 'India', '24')]
